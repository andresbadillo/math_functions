# %% [markdown]
# <a href="https://colab.research.google.com/github/andresbadillo/math_functions/blob/master/Curso_funciones_matematicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Curso Funciones Matemáticas

# %%
import matplotlib.pyplot as plt   # librería para graficar
import numpy as np                # librería para manejo de vectores y utilidades matemáticas

# %% [markdown]
# ##Clase 7 - Función lineal
#
# Tiene la forma de
# f(x)=mx+b
# donde  m  y  b   ∈R .
#
# m  puede ser calculada por:
# m=y2−y1x2−x1
#
# y  b  es el punto de corte con el eje  y . Su dominio es  Domf=(−∞,∞) . Su imagen es  Imf=(−∞,∞)

# %%
N = 100
m = -1
b = 5

def f(x):
  return m*x+b

x = np.linspace(-10,10,num=N)

y = f(x)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
plt.show()

# %% [markdown]
# ##CLase 8 - Funciones Polinómicas
#
# Tiene la forma de
# P(x)=anxn+an−1xn−1+...+a2x2+a1x+a1
#
# a una función que tiene esta forma se le llama polinomio de grado  n . A los elementos  a  los llamaremos coeficientes donde  a∈R .
#
# Por ejemplo:
#
# P(x)=2x7−x4+3x2+4
#
# que es un polinomio de grado 7.
#
# Funciones potencia
# Hay unas funciones que son un caso particular de las funciones polinómicas que son las funciones potencia, las cuales tienen la forma:
#
# f(x)=xa,a∈R
#
# Por ejemplo:
#
# f(x)=x2
#
# El dominio de  f(x)=x2  es  Domf=(−∞,∞) . Su imagen es  Imf=[0,∞)

# %%
def f(x):
  return (2*x**7) - (x**4) + (3*x**2) + 4

y = f(x)

x = np.linspace(-10,10,num=N)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
plt.show()

# %% [markdown]
# ##Clase 9 - Funciones trascendentes
# Son funciones que no pueden ser expresadas con polinomios.

# %% [markdown]
# ###Funciones Trigonométricas
#
# Algunos ejemplos son las funciones $cos(x)$, $sen(x)$ y $tan(x)$

# %%
def f(x):
  return np.tan(x)

y = f(x)

x = np.linspace(-10,10,num=N)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
plt.show()

# %% [markdown]
# ###Funciones Exponenciales
#
# Tienen la forma de $$f(x)=a^x$$ donde la base $a$ es una constante positiva. Un gran ejemplo de una función exponencial es usando la base como el número de euler:
#
# $$f(x)=e^x$$

# %%
def f(x):
  return np.exp(x)

y = f(x)

x = np.linspace(-10,10,num=N)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
plt.show()

# %% [markdown]
# ###Funciones Logarítmicas
#
# El logaritmo está definido por la **relación**:
#
# $$log_{b}(x) = n \Longleftrightarrow x=b^n$$
#
# donde:
#
#
#
# *   $b$ es la base.
# *   $n$ es el exponente al que está elevado la base.
# *   $x$ es el resultado de elevar la base $b$ al exponente $n$
#
# **Ejemplo:**
#
# Teniendo b=2 y n=8, entonces:
#
# $$2^8=256$$
#
# Por lo que $x=256$. Calculando el logaritmo base 2 de $x$ es:
#
# $$log_{2}(256) = 8$$

# %%
def f(x):
  return np.log2(x)

x = np.linspace(0.1,256,num=1000)

fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.grid()
plt.show()

# %% [markdown]
# ##Clase 10 - Funciones Seccionadas
#
# Son funciones que tienen diferentes valores definidos por un intervalo. Por ejemplo la función escalón de Heaviside:
#
# $$H(x) =
#      \begin{cases}
#         0, &\quad \text{para, } x < 0 \\
#         1,  &\quad\text{para. } x \ge 0 \\
#      \end{cases}
# $$

# %%
def H(x):
  Y = np.zeros(len(x))
  for idx,x in enumerate(x):
    if x >= 0:
      Y[idx] = 1
  return Y

N = 1000

x = np.linspace(-10,10,num=N)

y = H(x)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
plt.show()

# %% [markdown]
# ##Clase 11 - Funciones Compuestas

# %%
N = 1000

x = np.linspace(-10,10,num=N)

def g(x):
  return x**2

def f(x):
  return np.sin(x)

f_o_g = f(g(x))

fig, ax = plt.subplots()
ax.plot(x,f_o_g)
ax.grid()
plt.show()

# %% [markdown]
# ##Clase 12 - Como Manipular Funciones

# %% [markdown]
# ###Desplazamientos verticales y horizontales
#
# Siendo $c$ una constante mayor que cero, entonces la gráfica:
#
# - $y=f(x)+c$ se desplaza $c$ unidades hacia arriba.
# - $y=f(x)-c$ se desplaza $c$ unidades hacia abajo.
# - $y=f(x-c)$ se desplaza $c$ unidades hacia la derecha.
# - $y=f(x+c)$ se desplaza $c$ unidades hacia la izquierda.

# %%
N = 1000

def f(x):
  return x**2;

c = 5

x = np.linspace(-10,10, num=N)

# y = f(x) + c
# y = f(x) - c
# y = f(x - c)
y = f(x + c)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()

# %% [markdown]
# ###Alargamientos y compresiones
#
# Siendo $c$ una constante mayor que cero, entonces la gráfica:
#
# - $y=c \cdot f(x)$ alarga la gráfica verticalmente en un factor de $c$.
# - $y= \frac{1}{c} \cdot f(x)$ comprime la gráfica verticalmente en un factor de $c$.
# - $y=f(c \cdot x)$ comprime la gráfica horizontelmente en un factor de $c$.
# - $y= f(\frac{1}{c} \cdot x )$ alarga la gráfica horizontelmente en un factor de $c$.

# %%
N = 1000

def f(x):
  return np.sin(x);

c = 2

x = np.linspace(-15,15, num=N)

# y = f(x)
# y = c*f(x)
# y = (1/c)*f(x)
# y = f(c*x)
y = f((1/c)*x)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# %% [markdown]
# ###Reflexiones
#
# - $y=-f(x)$ refleja la gráfica respecto al eje x.
# - $y=f(-x)$ refleja la gráfica respecto al eje y.

# %%
N = 1000

def f(x):
  return x**3;

x = np.linspace(-10,10, num=N)

# y = f(x)
# y = -f(x)
y = f(-x)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# %% [markdown]
# ##Clase 15 - Funciones de Activación

# %%
N = 1000
x = np.linspace(-5,5, num=N)

# %% [markdown]
# ###Función Lineal
# $$y=mx+b$$

# %%
def f(x):
  return x

plt.plot(x, f(x))
plt.grid()

# %% [markdown]
# ###Función escalón o de Heaviside
# $$H(x) =
#      \begin{cases}
#         0, &\quad \text{para, } x < 0 \\
#         1,  &\quad\text{para. } x \ge 0 \\
#      \end{cases}
# $$

# %%
def H(x):
  Y = np.zeros(len(x))
  for idx,x in enumerate(x):
    if x>=0:
      Y[idx]=1
  return Y


N=1000


y = H(x)

plt.plot(x,y)
plt.grid()

# %% [markdown]
# ###Función sigmoide
#
# $$f(x)=\frac{1}{1-e^{-x}}$$

# %%
def f(x):
  return 1/(1 + np.exp(-x))


N=1000

y = f(x)

plt.plot(x,y)
plt.grid()

# %% [markdown]
# ###Función tangente hiperbólica
#
# $$f(x)=\frac{2}{1+e^{-2x}}-1$$

# %%
def f(x):
  return np.tanh(x)


N=1000

y = f(x)

plt.plot(x,y)
plt.grid()

# %% [markdown]
# ###Función ReLU
#
# $$R(x)=max(0,x)$$

# %%
def f(x):
  return np.maximum(x,0)


N=1000

y = f(x)

plt.plot(x,y)
plt.grid()
